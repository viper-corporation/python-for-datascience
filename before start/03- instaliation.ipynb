# %% [markdown]
# #  installation

# %% [markdown]
# its a short file for show you what you need to install and how to start them for this course  :

# %% [markdown]
# ## 1. python

# %% [markdown]
# you can download last version of python [here](https://www.python.org/downloads/) there is no need to install python in mac and linux

# %% [markdown]
# dont forget this tik :

# %% [markdown]
# ![photo_2022-10-19_15-24-16.jpg](attachment:82074c1c-bb18-4181-8d32-b75c06c6a148.jpg)

# %% [markdown]
# after install python The first way to work with Python in Windows is through an interactive session. To get an interactive session started, just open the Command Prompt. Search for cmd on the toolbar, then hit Enter. Once the command prompt is open, simply type ``python --version`` and hit Enter again. if you see the python version that means you install python successfully

# %% [markdown]
# for mac and linux users just open terminal and type ``python --version``

# %% [markdown]
# ## 2. anaconda

# %% [markdown]
# > Anaconda was built by data scientists, for data scientists.

# %% [markdown]
# using anaconda has many perpose but know we just learn about jupyter notebook and jupyter lab

# %% [markdown]
# so what is jupyter notebook and jupyter lab ?

# %%
a
# Out:
# 0

# %% [markdown]
# * ### what is jupyter

# %% [markdown]
# The Jupyter Notebook is an incredibly powerful tool for interactively developing and presenting data science projects.

# %% [markdown]
# * ### what is notebook

# %% [markdown]
# it’s a **single document** where you can run code, display the output, and also add explanations, formulas, charts, and make your work more transparent, understandable, repeatable, and shareable.**now a major part of the data science workflow at companies across the globe.**

# %% [markdown]
# Best of all, as part of the open source Project Jupyter, Jupyter Notebooks are completely free. You can download the software as part of the [Anaconda data science toolkit](https://www.anaconda.com/products/distribution).

# %% [markdown]
# ## start your first notebook

# %% [markdown]
# for starting your first notebook follow bellow steps :

# %% [markdown]
# 1) **install anaconda**

# %% [markdown]
# 2) **search anaconda in your windows search bar** <br>
# you can see tow results for anaconda![jupyter6.png](attachment:242edebf-e31f-43df-a87f-fc9fd035a8f3.png)

# %% [markdown]
# first one in this picture is CLI(command-line interface) of anaconda and second one is graphical version of anaconda

# %% [markdown]
# **most programmers and data scintists prefer CLI, so we continue steps with CLI**

# %% [markdown]
# 3) **open CLI** <br>
# for open CLI right click on it and choose run as adminestor
# ![download.png](attachment:364df96a-10b5-4a5b-9da4-909821d0c332.png)

# %% [markdown]
# after that you can see picture bellow. the red rectangle shows your envirment name and green rectangle is your current working space
#
# ![jupyter1.PNG](attachment:7b4be52b-67d7-482d-b3bf-41e7d8320755.PNG)

# %% [markdown]
# 4) change work space <br>
# by typing **your_partion_name:** you can change your current partition
# for example if you want go to drive e you should type e:
#
# ![jupyter2.PNG](attachment:6591950f-166c-4a53-8745-6b660234e7b5.PNG)

# %% [markdown]
# after that you can navigate in your folders with cd + your_folder_name command wich refers to change directory![jupyter3.PNG](attachment:6436940d-be66-4fed-93ef-bcf1d588fcdf.PNG)

# %% [markdown]
# **some notes abouts cd :**
#    * if there is space in your address you should add ""
#
#    ![jupyter7.PNG](attachment:711243e3-18bb-498e-aa6a-f2e767f76390.PNG)
#
#    * you can enter your folder name first characters and then press tab button and it automatically compelete the name

# %% [markdown]
# 5) **run jupyter notebook or jupyter lab** <br>
# enter **jupyter notebook** or **jupyter lab** in your terminal
#
# ![jupyter4.PNG](attachment:1d92e36a-546d-4f3f-8691-80d428ed94b0.PNG)
#
# after seconds jupyter will open in your default browser **Jupyter’s Notebooks and dashboard are web apps, and Jupyter starts up a local Python server to serve these apps to your web browser, making it essentially platform-independent and opening the door to easier sharing on the web.**

# %% [markdown]
# ![jupyter5.PNG](attachment:39699e05-e608-4bbe-b7d7-bc768ae878d2.PNG)

# %% [markdown]
# * red rectangle : its your localhost name. jupyter almost open on port 8888. **Localhost is not a website, but indicates that the content is being served from your local machine: your own computer.**
#
# * green rectangle : its your working space files and folders
# * blue rectangle : you can create a new note book or uplaod a notebook from your system

# %% [markdown]
# * **.ipynb file:**

# %% [markdown]
# **The short answer**: each .ipynb file is one notebook, so each time you create a new notebook, a new  .ipynb file will be created.
#
# **The longer answer:** Each .ipynb file is a text file that describes the contents of your notebook in a format called JSON. Each cell and its contents, including image attachments that have been converted into strings of text, is listed therein along with some metadata.
#
# who to create ipynb file? just click on new and select your kernel

# %% [markdown]
# now how to start **jupyter lab** ?
#
# just type jupyter la instead of jupyter notebook in anaconda terminal
#
# after seconds jupyter will open in your default browser :

# %% [markdown]
# ![Screenshot from 2023-04-13 10-17-02.png](attachment:937f131e-545d-42ca-9c32-c8ffb77c1038.png)

# %% [markdown]
# who to create ipynb file in jupyter lab? just click on + button and select notebook

# %% [markdown]
# ## 3. install visual studio code

# %% [markdown]
# you can download last version of python [here](https://code.visualstudio.com/download) there is no need to install python in mac and linux
