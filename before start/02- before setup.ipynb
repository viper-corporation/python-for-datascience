# %% [markdown]
# # Before Setup

# %% [markdown]
# * [intro to operating systems](#intro-to-operating-systems)
#     * [operating systm diagram](#operating-systm-diagram)
#     * [Process Management in OS](#Process-Management-in-OS)
#     * [operating systems directory structure](#operating-systems-directory-structure)

# %% [markdown]
# ## intro to operating systems

# %% [markdown]
# An operating system acts as an intermediary between the **user of a computer** and **computer hardware.** The purpose of an operating system is to provide an environment in which a user can execute programs conveniently and efficiently.

# %% [markdown]
# An operating system is software that manages computer hardware.

# %% [markdown]
# ![Untitled.jpeg](attachment:9bc34de0-2c0d-4be4-a389-da10d3189fa4.jpeg)

# %% [markdown]
# * #### operating systm diagram

# %% [markdown]
# ![download.png](attachment:14f2296d-813b-4a49-b1f0-04acc561dc9d.png)

# %% [markdown]
# this is a diagram which represents the basic structure and components of a computer system.
# first of all at the lowermost level we have the **computer hardware.**

# %% [markdown]
# Application Programs are the programs or the software,
# that are used to perform a specific task and that can be **directly used by users.**

# %% [markdown]
# The **Operating System** resides between the computer hardware and the users.

# %% [markdown]
# * #### Process Management in OS

# %% [markdown]
# ![Screenshot from 2023-04-12 15-29-52.png](attachment:5d06cb90-bc9b-44b6-b657-297645a794da.png)

# %% [markdown]
# A Program does nothing unless its instructions are executed by a CPU. A program in execution is called a process. In order to accomplish its task, process needs the computer resources.
#
# There may exist more than one process in the system which may require the same resource at the same time. Therefore, the operating system has to manage all the processes and the resources in a convenient and efficient way.
#
# Some resources may need to be executed by one process at one time to maintain the consistency otherwise the system can become inconsistent and deadlock may occur.
#
# The operating system is responsible for the following activities in connection with Process Management:
#
#     Scheduling processes and threads on the CPUs.
#     Creating and deleting both user and system processes.
#     Suspending and resuming processes.
#     Providing mechanisms for process synchronization.
#     Providing mechanisms for process communication.

# %% [markdown]
# * ### operating systems directory structure
#     * windows :
#
#     ![presentation4.webp](attachment:f8724355-678e-4164-a339-fa150a257641.webp)
#
#     * mac & linux :
#
#     ![httpatomoreillycomsourceoreillyimages1448104.png](attachment:2911c825-c9a2-48c9-ba9d-a30e2b9bf246.png)

# %% [markdown]
# ## Terminal Basics

# %% [markdown]
#  command line is a text interface to your computer. Often referred to as the shell, terminal, console, prompt or various other names,

# %% [markdown]
# it can give the appearance of being complex and confusing to use.

# %% [markdown]
# * ### Opening a terminal

# %% [markdown]
# on mac search terminal and open it

# %% [markdown]
# on linux press **ctrl+alt+t**

# %% [markdown]
# on wibdows search **cmd** and open terminal

# %% [markdown]
# ![Screenshot from 2023-04-13 15-45-56.png](attachment:70fb380e-4caf-4032-b06b-46b091e4ed7a.png)

# %% [markdown]
# $ pwd
#
# this commond show your working directory
#
# Now to the command itself. pwd is an abbreviation of "**p**rint **w**orking **d**irectory". All it does is print out the shell’s current working directory. But what’s a working directory?
#
# One important concept to understand is that the shell has a notion of a default location in which any file operations will take place. This is its working directory.

# %% [markdown]
# You can change the working directory using the cd command, an abbreviation for ‘change directory’. Try typing the following:

# %% [markdown]
# $ cd /
#
# $ pwd

# %% [markdown]
# To go up to the parent directory, in this case back to /, use the special syntax of two dots (..) when changing directory (note the space between cd and .., unlike in DOS you can’t just type cd.. as one command):
#
# $ cd ..

# %% [markdown]
# ### commond structure

# %% [markdown]
# the general command structure goes like this.
#
# 1. You type out the command name. So it would be like date or echo.
# 2. Then you give the comments of options to customize its behavior.
# 3. Then you give the command some inputs to actually operate on.

# %% [markdown]
# **Command Name:** the first thing you type is the command name. Now that lets the shell know what program you actually want to run.

# %% [markdown]
# **Inputs** : It's important to note that not all commands actually require inputs. Some inputs are optional. For example the date command doesn't strictly require an input.
# So for example if we take the cow command I could just type cow OK and press enter and I would get this month's calendar. But to customize the behavior I can give it one or more inputs: cal 2021, cal 12 2017

# %% [markdown]
# **Options:** That's common for commands to be preceded by dashes and hyphens and things:
#
# ``cal -y, date -u (UTC time)``
#
# So sometimes options actually have long form names proceded by --:
#
# ``date --universal``
