# %% [markdown]
# # Welcome To Python For Datascience Course

# %% [markdown]
# * [History of Data Science](#History-of-Data-Science)
# * [the Data Science Venn Diagram](#the-Data-Science-Venn-Diagram)
# * [the Data Science Hierarchy of needs](#the-Data-Science-Hierarchy-of-needs)
# * [Roles in data science](#Roles-in-data-science)
# * [Datascience path way](#Datascience-path-way)
# * [Programming(we learn this part in next 6 month)](#Programming(we-learn-this-part-in-next-6-month))
# * [Data Science loves jupyter](#Data-Science-loves-jupyter)

# %% [markdown]
# hello everyone !!

# %% [markdown]
# my name is **Rasool Ahadi** and im here with **Amirhossein Dehghan** to learn you Python for datascience

# %% [markdown]
# ### **let's start :**

# %% [markdown]
# what we are going to do in this session is We are going to have a brief, accessible and non-technical overview of the field of Data Science.

# %% [markdown]
# what is the goal of datascience?

# %% [markdown]
# Data science is not about making complicated models. It's not about making awesome visualizations
# It's not about writing code **data science is about using data to create as much impact as possible for your company**
# Now impact can be in the form of multiple things
# It could be in the form of insights in the form of data products or in the form of product recommendations for a company
# Now to do those things, then you need tools like making complicated models or data visualizations or writing code

# %% [markdown]
# > and so in this session what we are trying to do is give you a **map to the field of Data Science** and how you can use it and so now you have the map in your hands and you can

# %% [markdown]
# <hr>

# %% [markdown]
# ## History of Data Science

# %% [markdown]
# Before data science, we popularized the term **data mining** in an article called **from data mining to knowledge discovery in databases** in 1996 in which it referred to the overall process of discovering useful information from data.

# %% [markdown]
# in 2001, William S. Cleveland wanted to bring data mining to another level He did that by **combining computer science with data mining.**

# %% [markdown]
# He made **statistics** a lot more technical which he believed would expand the possibilities of data mining and produce a powerful force for innovation Now you can take advantage of compute power for statistics and he called this combination **data science.**

# %% [markdown]
# Around this time this is also when web 2.0 emerged where websites are no longer just a digital pamphlet, but a medium for a shared experience amongst millions and millions of users. this are websites like myspace, facebook and youtube

# %% [markdown]
# And guess what?
#
# **That's a lot of data** so much data, it became too much to handle using traditional technologies. So we call this Big Data.

# %% [markdown]
# it became too much to handle using traditional technologies. So we call this **Big Data.**

# %% [markdown]
# so the rise of big data in
# 2010 sparked the rise of data science to support the needs of the businesses to draw insights from their massive unstructured data sets

# %% [markdown]
# So then the **journal of data science** described data science as
# `almost everything that has something to do with data collecting analyzing modeling. Yet the most important part is its applications. All sorts of applications.`

# %% [markdown]
# it made it possible to train machines with a **data-driven approach**
# rather than a **knowledge driven approach.**

# %% [markdown]
# All the theoretical papers about recurring neural networks support vector machines became feasible

# %% [markdown]
# Deep learning was no longer an academic concept in these thesis paper
# It became a tangible useful class of machine learning that would affect our everyday lives.

# %% [markdown]
# So machine learning and AI dominated the media overshadowing every other aspect of data science
# like exploratory analysis, experimentation, ... And skills we traditionally called business intelligence

# %% [markdown]
# So now the general public think of data science
# researchers focused on machine learning and AI but the industry is hiring data scientists as analysts

# %% [markdown]
# **Being a good data scientist isn't about how advanced your models are
# It's about how much impact you can have with your work.**

# %% [markdown]
# ## the Data Science Venn Diagram

# %% [markdown]
# we're going to first say thanks to **Drew Conway**, the guy who came up with this

# %% [markdown]
# ![Untitled.png](attachment:f137e9b3-e11f-45a9-873a-80bad4582786.png)

# %% [markdown]
# ## coding :

# %% [markdown]
# The reason coding is important is because it helps you **gather and prepare the data.** Because a lot of the data comes from novel sources and is not necessarily ready for you to gather and it can be in very unusual formats. And so coding is important because it can require some real creativity to get
# the data from the sources to put it into your analysis. Now, a few kinds of coding that
# are important :

# %% [markdown]
# ![Screenshot from 2023-04-04 11-49-04.png](attachment:92872ddb-3d91-4fcb-86d0-bab150fceec3.png)

# %% [markdown]
# ## Math :

# %% [markdown]
#  in datascience you needed probability, some algebra, regression, etc.  And the reason you need the math is: because that is going to help you choose the appropriate procedures to answer the question with the
# data that you have. And probably even more importantly; it is going to help you diagnose problems when things don't go as expected

# %% [markdown]
# ## Domain :

# %% [markdown]
# the third element of the data science Venn Diagram is some sort of domain expertise. Think of it as expertise in the field that you're in.
# You need to know about the goals of that field, the methods that are used, and the constraints that people come across. And it's important because whatever your results are, you need to be able to implement them well.

# %% [markdown]
# peoples in datasience :

# %% [markdown]
# * **code :** coders who can do math, stats (more common)
# * **stats. :** statisticians who can code (less common)
# * **domain :** buisiness people who can code & do numbers(least common)

# %% [markdown]
# **in sum:**
# * several fields DS
# * diverse skills needed

# %% [markdown]
# ## the Data Science Hierarchy of needs

# %% [markdown]
# The Data Science Hierarchy of Needs, developed after Maslow’s Hierarchy of Needs, is a model that shows the needs of data science practitioners and helps them understand and prioritise their projects.

# %% [markdown]
# ![1 7IMev5xslc9FLxr9hHhpFw.jpeg](attachment:3b99ed87-956b-4f51-b9c3-e512ef1fb50f.jpeg)

# %% [markdown]
# ## Roles in data science

# %% [markdown]
# ![Screenshot from 2023-04-06 14-48-01.png](attachment:9a4d88e5-2f34-48d5-b358-54821bad8174.png)

# %% [markdown]
# ## Datascience path way

# %% [markdown]
# In data science, you can take the various steps and you can put them into a couple of general categories

# %% [markdown]
# **first: planning** :

# %% [markdown]
# * define goals
# * organize resoueces
# * coordinate people

# %% [markdown]
# **second: data prep:**

# %% [markdown]
# * get data
# * clean data
# * explore data
# * refine data

# %% [markdown]
# **third: modeling**:

# %% [markdown]
# * create model
# * validate model
# * evaluate model
# * refine model

# %% [markdown]
# **last part : follow up:**

# %% [markdown]
# * present model
# * deploy model
# * revisit model
# * archive assets

# %% [markdown]
# > so in sum **DS in not just coding**

# %% [markdown]
# ## Programming(we learn this part in next 6 month)

# %% [markdown]
# what we are going to do in this
# section is we're going to take a little look at the tools of Data Science. So, I am inviting you to know your tools, but probably even more important than that
# is to know their proper place. Now, I mention that because a lot of the times when people
# talk about data tools, they talk about it as though that were the same thing as data science

# %% [markdown]
# ![Screenshot from 2023-04-04 13-53-12.png](attachment:df5bc8da-8744-4a42-9fd6-1340f4b7c252.png)

# %% [markdown]
# > DS is more than coding and tools

# %% [markdown]
# > **but you will need at least a few tools**

# %% [markdown]
# some data tools:
#
# applications :
# * spreadsheets
# * tableau
# * spss
#
# programming languages :
#
# * web data
# * python
# * R
# * SQL
# * Regex

# %% [markdown]
# what is programming language?
#
# A programming language is a system of notation for writing computer programs.

# %% [markdown]
# programming languages categories based on the connection with hardware :
#
#     high-level languages :
#
#       easy for human
#       like : python, javascript
#
#     middle-level :
#
#       like c, c++, java
#
#     low-level languages :
#
#       easy for machine
#       like :  assembley

# %% [markdown]
# **Python** is the **only general purpose programming language.**
# It's the only one that can be theoretically used to develop any kind of application that you want. That gives it some special powers compared to all the others, most of which

# %% [markdown]
# why python?
# * general purpose
# * great community
# * easy to use
# * thousands of packages

# %% [markdown]
# The Zen of Python is a collection of 19 "guiding principles" for writing computer programs that influence the design of the Python programming language. Software engineer Tim Peters wrote this set of principles and posted it on the Python mailing list in 1999. Peters's list left open a 20th principle "for Guido to fill in", referring to Guido van Rossum, the original author of the Python language. The vacancy for a 20th principle has not been filled.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# interfaces for python :

# %% [markdown]
# * python's IDLE
# * Terminal/IDE
# * jupyter/IPython

# %% [markdown]
# > **Data Science loves jupyter**
# The Jupyter is a server-client applications that allows editing and running notebook documents via a web browser and that because **markdown cells, inline graphics, easy to organize & present**

# %% [markdown]
# ### most needed packages in python for Data Science:

# %% [markdown]
# * numpy
# * pandas
# * matplotlib and seaborn
# * scikit-learn
