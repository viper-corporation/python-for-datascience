# %% [markdown]
# # conditional statments

# %% [markdown]
# * [if statment](#if-statment)
# * [else in conditional statment](#else-in-conditional-statment)
# * [elif in conditional statment](#elif-in-conditional-statment)
# * [One-Line if Statements](#One-Line-if-Statements)
# * [Conditional Expressions](#Conditional-Expressions)
# * [pass and ...](#pass-and-...)

# %% [markdown]
# every thing we learn till now was **sequential execution** , in which statements are always performed one after the next, in exactly the order specified.

# %% [markdown]
# But the world is often more complicated than that. Frequently, a program needs to skip over some statements, execute a series of statements repetitively, or choose between alternate sets of statements to execute.

# %% [markdown]
# ## if statment

# %% [markdown]
# ![download.png](attachment:604d3d1c-2d28-4849-b7ce-16178b4e728b.png)

# %% [markdown]
# **Note:** In the Python documentation, a group of statements defined by indentation is often referred to as a **suite**. This tutorial series uses the terms **block and suite** interchangeably.

# %%
y = 0
x = 5
if x>y:
    print("x is bigger than y")
print("this is out side of if")
# Out:
# x is bigger than y
# this is out side of if

# %%
if x>y and y!=0:
    print('yes')

# %%
if 'quux' in ['foo', 'bar', 'baz']:
    print('yes')

# %%
if 'aul' in 'grault':
    print('yes')
# Out:
# yes

# %%
if 'foo' in ['foo', 'bar', 'baz']:        
    print('Outer condition is true')      
    if 10 > 20:                           
        print('Inner condition 1')
# Out:
# Outer condition is true

# %% [markdown]
# examples :

# %% [markdown]
# ![conditional-statment-1.PNG](attachment:9c612c4d-10d2-4ba8-8765-bf2ee241d3bd.PNG)

# %% [markdown]
# ## else in conditional statment

# %% [markdown]
# ![conditional-statment-2.PNG](attachment:9e4da46e-e5f7-43ca-9338-5e58a913b2fe.PNG)

# %%
x = 20
if x < 50:
    print('(first suite)')
    print('x is small')
else:
    print('(second suite)')
    print('x is large')
# Out:
# (first suite)
# x is small

# %% [markdown]
# ## elif in conditional statment

# %% [markdown]
# ```python
# if <expr>:
#     <statement(s)>
# elif <expr>:
#     <statement(s)>
# elif <expr>:
#     <statement(s)>
#     ...
# else:
#     <statement(s)>
# ```

# %%
name = 'Joe'
if name == 'Fred':
    print('Hello Fred')
elif name == 'Xander':
    print('Hello Xander')
elif name == 'Joe':
    print('Hello Joe')
elif name == 'Arnold':
    print('Hello Arnold')
else:
    print("I don't know who you are!")
# Out:
# Hello Joe

# %% [markdown]
# ## One-Line if Statements

# %% [markdown]
# ```python
# if <expr>: <statement>
# ```

# %% [markdown]
# There can even be more than one `<statement>` on the same line, separated by semicolons:
#
# ```python
# if <expr>: <statement_1>; <statement_2>; ...; <statement_n>
# ```

# %%
if 'f' in 'foo': print('1')
# Out:
# 1

# %%
if 'f' in 'foo': print('1'); print('2'); print('3')
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## Conditional Expressions

# %% [markdown]
# In its simplest form, the syntax of the conditional expression is as follows:

# %% [markdown]
# ```python
# <expr1> if <conditional_expr> else <expr2>
# ```

# %% [markdown]
# This is different from the if statement forms listed above because it is not a control structure that directs the flow of program execution. It acts more like an operator that defines an expression. In the above example, `<conditional_expr>` is evaluated first. If it is true, the expression evaluates to `<expr1>`. If it is false, the expression evaluates to `<expr2>`

# %%
raining = False
print("Let's go to the", 'beach' if not raining else 'library')
# Out:
# Let's go to the beach

# %%
raining = True
print("Let's go to the", 'beach' if not raining else 'library')
# Out:
# Let's go to the library

# %%
'yes' if ('qux' in ['foo', 'bar', 'baz']) else 'no'
# Out:
# 'no'

# %% [markdown]
# A common use of the conditional expression is to select variable assignment. For example, suppose you want to find the larger of two numbers. Of course, there is a built-in function max() that does just this (and more) that you could use. But suppose you want to write your own code from scratch.

# %%
a =4
b = 5
if a > b:
    m = a
else:
    m = b
m
# Out:
# 5

# %%
a=4
b=5
m = a if a > b else b
m
# Out:
# 5

# %% [markdown]
# Conditional expressions can also be chained together, as a sort of alternative `if/elif/else` structure, as shown here:

# %%
x =1
s = ('foo' if (x == 1) else
     'bar' if (x == 2) else
     'baz' if (x == 3) else
     'qux' if (x == 4) else
     'quux'
    )
s
# Out:
# 'foo'

# %% [markdown]
# ## pass and ...
# Occasionally, you may find that you want to write what is called a code stub: a placeholder for where you will eventually put a block of code that you haven’t implemented yet.

# %%
name = 'rasool'

if name == 'rasool':
    # TODO: add name to database
    pass # or ...
else:
    # TODO: warn user about registeration
    ... # or oass

print('here')
# Out:
# here
